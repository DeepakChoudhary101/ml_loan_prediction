# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("train.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df[['ApplicantIncome']]
# Out:
#      ApplicantIncome
# 0               5849
# 1               4583
# 2               3000
# 3               2583
# 4               6000
# ..               ...
# 609             2900
# 610             4106
# 611             8072
# 612             7583
# 613             4583
#
# [614 rows x 1 columns]

# %%
df[['CoapplicantIncome','Loan_Amount_Term']]
# Out:
#      CoapplicantIncome  Loan_Amount_Term
# 0                  0.0             360.0
# 1               1508.0             360.0
# 2                  0.0             360.0
# 3               2358.0             360.0
# 4                  0.0             360.0
# ..                 ...               ...
# 609                0.0             360.0
# 610                0.0             180.0
# 611              240.0             360.0
# 612                0.0             360.0
# 613                0.0             360.0
#
# [614 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#handle numerical missing data
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#handling categorical missing data
# Out:
# 146.41216216216216

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#exploratory data analysis
#pip install seaborn
#categorical data
import seaborn as sns
sns.countplot(data=df, x='Gender')
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='count'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
sns.countplot(data=df,x='Dependents')
# Out:
# <AxesSubplot: xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(data=df,x='Married')
# Out:
# <AxesSubplot: xlabel='Married', ylabel='count'>

# %%
#numerical data

# sns.displot(df.CoapplicantIncome)
sns.displot(df.CoapplicantIncome, kde=True)

# %%
sns.displot(df.LoanAmount, kde=True)

# %%
sns.displot(df.Credit_History,kde=True)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#created new columns

# %%
df['Total_income']=df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
#data transformation

# %%
df['ApplicantIncomeLog']=np.log(df['ApplicantIncome'])

# %%
sns.displot(df.ApplicantIncomeLog,kde=True)

# %%
sns.displot(df.ApplicantIncome,kde=True)

# %%
df['LoanAmountLog']=np.log(df['LoanAmount'])
sns.displot(df.LoanAmountLog,kde=True)

# %%
df['Loan_Amount_TermLog']=np.log(df['Loan_Amount_Term'])
sns.displot(df.Loan_Amount_TermLog,kde=True)

# %%
df['Total_incomeLog']=np.log(df['Total_income'])
sns.displot(df.Total_incomeLog,kde=True)

# %%
sns.displot(df.Credit_History,kde=True)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income  ApplicantIncomeLog  \
# ...

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income','Loan_ID']
df=df.drop(columns=cols,axis=1)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.674026            NaN
# 1         Rural           N            8.430109       4.852030
# 2         Urban           Y            8.006368       4.189655
# 3         Urban           Y            7.856707       4.787492
# 4         Urban           Y            8.699515       4.948760
#
#    Loan_Amount_TermLog  Total_incomeLog
# 0             5.886104         8.674026
# 1             5.886104         8.714568
# ...

# %%
#value count
df.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
df.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %% [markdown]
#     handling categorical data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               601 non-null    object
#  1   Married              611 non-null    object
#  2   Dependents           599 non-null    object
#  3   Education            614 non-null    object
#  4   Self_Employed        582 non-null    object
#  5   Credit_History       564 non-null    float64
#  6   Property_Area        614 non-null    object
#  7   Loan_Status          614 non-null    object
#  8   ApplicantIncomeLog   614 non-null    float64
#  9   LoanAmountLog        592 non-null    float64
#  10  Loan_Amount_TermLog  600 non-null    float64
#  11  Total_incomeLog      614 non-null    float64
# dtypes: float64(5), object(7)
# memory usage: 57.7+ KB

# %%
#store all object columns
d1 = pd.get_dummies(df['Gender'], drop_first= True)
d2 = pd.get_dummies(df['Married'], drop_first= True)
d3 = pd.get_dummies(df['Dependents'], drop_first= True)
d4 = pd.get_dummies(df['Education'], drop_first= True)
d5 = pd.get_dummies(df['Self_Employed'], drop_first= True)
d6 = pd.get_dummies(df['Property_Area'], drop_first= True)



df1 = pd.concat([df, d1, d2, d3, d4, d5, d6], axis = 1)
df=df1

cols = ['Gender', 'Married', "Dependents", "Education", "Self_Employed", 'Property_Area']
df = df.drop(columns=cols, axis=1)

# %%
df.head()
# Out:
#    Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0             1.0           Y            8.674026            NaN
# 1             1.0           N            8.430109       4.852030
# 2             1.0           Y            8.006368       4.189655
# 3             1.0           Y            7.856707       4.787492
# 4             1.0           Y            8.699515       4.948760
#
#    Loan_Amount_TermLog  Total_incomeLog  Male    Yes      1      2     3+  \
# 0             5.886104         8.674026  True  False  False  False  False
# 1             5.886104         8.714568  True   True   True  False  False
# 2             5.886104         8.006368  True   True  False  False  False
# 3             5.886104         8.505323  True   True  False  False  False
# 4             5.886104         8.699515  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# 1         False  False      False  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Credit_History       564 non-null    float64
#  1   Loan_Status          614 non-null    object
#  2   ApplicantIncomeLog   614 non-null    float64
#  3   LoanAmountLog        592 non-null    float64
#  4   Loan_Amount_TermLog  600 non-null    float64
#  5   Total_incomeLog      614 non-null    float64
#  6   Male                 614 non-null    bool
#  7   Yes                  614 non-null    bool
#  8   1                    614 non-null    bool
#  9   2                    614 non-null    bool
#  10  3+                   614 non-null    bool
#  11  Not Graduate         614 non-null    bool
#  12  Yes                  614 non-null    bool
#  13  Semiurban            614 non-null    bool
#  14  Urban                614 non-null    bool
# ...

# %%
df.head()
# Out:
#    Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0             1.0           Y            8.674026            NaN
# 1             1.0           N            8.430109       4.852030
# 2             1.0           Y            8.006368       4.189655
# 3             1.0           Y            7.856707       4.787492
# 4             1.0           Y            8.699515       4.948760
#
#    Loan_Amount_TermLog  Total_incomeLog  Male    Yes      1      2     3+  \
# 0             5.886104         8.674026  True  False  False  False  False
# 1             5.886104         8.714568  True   True   True  False  False
# 2             5.886104         8.006368  True   True  False  False  False
# 3             5.886104         8.505323  True   True  False  False  False
# 4             5.886104         8.699515  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# 1         False  False      False  False
# ...

# %%
# Assuming 'my_column' is the column with boolean values
# df['Male'] = df['Male'].astype('uint8')
# df['Yes'] = df['Yes'].astype('uint8')
df['1'] = df['1'].astype('uint8')
df['2'] = df['2'].astype('uint8')
df['3+'] = df['3+'].astype('uint8')
df['Not Graduate'] = df['Not Graduate'].astype('uint8')
df['Semiurban'] = df['Semiurban'].astype('uint8')
df['Urban'] = df['Urban'].astype('uint8')

# %%
df.head()
# Out:
#    Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0             1.0           Y            8.674026            NaN
# 1             1.0           N            8.430109       4.852030
# 2             1.0           Y            8.006368       4.189655
# 3             1.0           Y            7.856707       4.787492
# 4             1.0           Y            8.699515       4.948760
#
#    Loan_Amount_TermLog  Total_incomeLog  Male  Yes  1  2  3+  Not Graduate  \
# 0             5.886104         8.674026     1    0  0  0   0             0
# 1             5.886104         8.714568     1    1  1  0   0             0
# 2             5.886104         8.006368     1    1  0  0   0             0
# 3             5.886104         8.505323     1    1  0  0   0             1
# 4             5.886104         8.699515     1    0  0  0   0             0
#
#    Yes  Semiurban  Urban
# 0    0          0      1
# 1    0          0      0
# 2    1          0      1
# ...

# %%
df.tail()
# Out:
#      Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 609             1.0           Y            7.972466       4.262680
# 610             1.0           Y            8.320205       3.688879
# 611             1.0           Y            8.996157       5.533389
# 612             1.0           Y            8.933664       5.231109
# 613             0.0           N            8.430109       4.890349
#
#      Loan_Amount_TermLog  Total_incomeLog  Male  Yes  1  2  3+  Not Graduate  \
# 609             5.886104         7.972466     0    0  0  0   0             0
# 610             5.192957         8.320205     1    1  0  0   1             0
# 611             5.886104         9.025456     1    1  1  0   0             0
# 612             5.886104         8.933664     1    1  0  1   0             0
# 613             5.886104         8.430109     0    0  0  0   0             0
#
#      Yes  Semiurban  Urban
# 609    0          0      0
# 610    0          0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Credit_History       564 non-null    float64
#  1   Loan_Status          614 non-null    object
#  2   ApplicantIncomeLog   614 non-null    float64
#  3   LoanAmountLog        592 non-null    float64
#  4   Loan_Amount_TermLog  600 non-null    float64
#  5   Total_incomeLog      614 non-null    float64
#  6   Male                 614 non-null    uint8
#  7   Yes                  614 non-null    uint8
#  8   1                    614 non-null    uint8
#  9   2                    614 non-null    uint8
#  10  3+                   614 non-null    uint8
#  11  Not Graduate         614 non-null    uint8
#  12  Yes                  614 non-null    uint8
#  13  Semiurban            614 non-null    uint8
#  14  Urban                614 non-null    uint8
# ...

# %%
df.describe()
# Out:
#        Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_TermLog  \
# count      564.000000          614.000000     592.000000           600.000000
# mean         0.842199            8.341213       4.857444             5.801300
# std          0.364878            0.645263       0.505142             0.316072
# min          0.000000            5.010635       2.197225             2.484907
# 25%          1.000000            7.964677       4.605170             5.886104
# 50%          1.000000            8.246040       4.852030             5.886104
# 75%          1.000000            8.664750       5.123964             5.886104
# max          1.000000           11.302204       6.551080             6.173786
#
#        Total_incomeLog        Male         Yes           1           2  \
# count       614.000000  614.000000  614.000000  614.000000  614.000000
# mean          8.669414    0.796417    0.648208    0.166124    0.164495
# ...

# %% [markdown]
# #done train data

# %% [markdown]
# now we are going to work on test

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#access csv data to a pandas dataframe
pf=pd.read_csv("test.csv")

# %%
pf.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
pf.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#filling numerical missing data
pf['LoanAmount']=pf['LoanAmount'].fillna(pf['LoanAmount'].mean())
pf['Loan_Amount_Term']=pf['Loan_Amount_Term'].fillna(pf['Loan_Amount_Term'].mean())
pf['Credit_History']=pf['Credit_History'].fillna(pf['Credit_History'].mean())
#filling categorial data
pf['Gender']=pf['Gender'].fillna(pf['Gender'].mode()[0])
pf['Dependents']=pf['Dependents'].fillna(pf['Dependents'].mode()[0])
pf['Self_Employed']=pf['Self_Employed'].fillna(pf['Self_Employed'].mode()[0])

# %%
#add new column  total_income
pf['Total_income']=pf['ApplicantIncome']+pf['CoapplicantIncome']

# %%
#apply log transformation to the attribue for distribute to noraml
pf['ApplicantIncomeLog']=np.log(pf['ApplicantIncome'])
pf['CoapplicantIncomeLog']=np.log(pf['CoapplicantIncome'])
pf['LoanAmountLog']=np.log(pf['LoanAmount'])
pf['Loan_Amount_Term_Log']=np.log(pf['Loan_Amount_Term'])
pf['Total_income_Log']=np.log(pf['Total_income'])

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income']
pf=pf.drop(columns=cols,axis=1)

# %%
pf.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    Credit_History Property_Area  ApplicantIncomeLog  CoapplicantIncomeLog  \
# 0        1.000000         Urban            8.651724                  -inf
# 1        1.000000         Urban            8.031385              7.313220
# 2        1.000000         Urban            8.517193              7.495542
# 3        0.825444         Urban            7.757906              7.842279
# 4        1.000000         Urban            8.094378                  -inf
#
#    LoanAmountLog  Loan_Amount_Term_Log  Total_income_Log
# 0       4.700480              5.886104          8.651724
# ...

# %%
t1=pd.get_dummies(pf['Gender'],drop_first=True)
t2=pd.get_dummies(pf['Married'],drop_first=True)
t3=pd.get_dummies(pf['Dependents'],drop_first=True)
t4=pd.get_dummies(pf['Education'],drop_first=True)
t5=pd.get_dummies(pf['Self_Employed'],drop_first=True)
t6=pd.get_dummies(pf['Property_Area'],drop_first=True)
pf1=pd.concat([pf,t1,t2,t3,t4,t5,t6],axis=1)
pf=pf1
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
pf=pf.drop(columns=cols,axis=1)

# %%
pf.head()
# Out:
#     Loan_ID  Credit_History  ApplicantIncomeLog  CoapplicantIncomeLog  \
# 0  LP001015        1.000000            8.651724                  -inf
# 1  LP001022        1.000000            8.031385              7.313220
# 2  LP001031        1.000000            8.517193              7.495542
# 3  LP001035        0.825444            7.757906              7.842279
# 4  LP001051        1.000000            8.094378                  -inf
#
#    LoanAmountLog  Loan_Amount_Term_Log  Total_income_Log  Male    Yes      1  \
# 0       4.700480              5.886104          8.651724  True   True  False
# 1       4.836282              5.886104          8.428581  True   True   True
# 2       5.337538              5.886104          8.824678  True   True  False
# 3       4.605170              5.886104          8.494129  True   True  False
# 4       4.356709              5.886104          8.094378  True  False  False
#
#        2     3+  Not Graduate    Yes  Semiurban  Urban
# ...

# %%
pf['Yes']=pf['Yes'].astype('uint8')
pf['Male']=pf['Male'].astype('uint8')
pf['1']=pf['1'].astype('uint8')
pf['2']=pf['2'].astype('uint8')
pf['3+']=pf['3+'].astype('uint8')
pf['Not Graduate']=pf['Not Graduate'].astype('uint8')
pf['Semiurban']=pf['Semiurban'].astype('uint8')
pf['Urban']=pf['Urban'].astype('uint8')

# %%
pf.head()
# Out:
#     Loan_ID  Credit_History  ApplicantIncomeLog  CoapplicantIncomeLog  \
# 0  LP001015        1.000000            8.651724                  -inf
# 1  LP001022        1.000000            8.031385              7.313220
# 2  LP001031        1.000000            8.517193              7.495542
# 3  LP001035        0.825444            7.757906              7.842279
# 4  LP001051        1.000000            8.094378                  -inf
#
#    LoanAmountLog  Loan_Amount_Term_Log  Total_income_Log  Male  Yes  1  2  3+  \
# 0       4.700480              5.886104          8.651724     1    1  0  0   0
# 1       4.836282              5.886104          8.428581     1    1  1  0   0
# 2       5.337538              5.886104          8.824678     1    1  0  1   0
# 3       4.605170              5.886104          8.494129     1    1  0  1   0
# 4       4.356709              5.886104          8.094378     1    0  0  0   0
#
#    Not Graduate  Yes  Semiurban  Urban
# ...

# %%
pf=pf.drop(columns=['CoapplicantIncomeLog'])

# %%
pf=pf.drop(columns=['Loan_ID'])
pf.head()
# Out:
#    Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0        1.000000            8.651724       4.700480              5.886104
# 1        1.000000            8.031385       4.836282              5.886104
# 2        1.000000            8.517193       5.337538              5.886104
# 3        0.825444            7.757906       4.605170              5.886104
# 4        1.000000            8.094378       4.356709              5.886104
#
#    Total_income_Log  Male  Yes  1  2  3+  Not Graduate  Yes  Semiurban  Urban
# 0          8.651724     1    1  0  0   0             0    0          0      1
# 1          8.428581     1    1  1  0   0             0    0          0      1
# 2          8.824678     1    1  0  1   0             0    0          0      1
# 3          8.494129     1    1  0  1   0             0    0          0      1
# 4          8.094378     1    0  0  0   0             1    0          0      1

# %% [markdown]
# #split datasets

# %%
df.head()
# Out:
#    Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0             1.0           Y            8.674026            NaN
# 1             1.0           N            8.430109       4.852030
# 2             1.0           Y            8.006368       4.189655
# 3             1.0           Y            7.856707       4.787492
# 4             1.0           Y            8.699515       4.948760
#
#    Loan_Amount_TermLog  Total_incomeLog  Male  Yes  1  2  3+  Not Graduate  \
# 0             5.886104         8.674026     1    0  0  0   0             0
# 1             5.886104         8.714568     1    1  1  0   0             0
# 2             5.886104         8.006368     1    1  0  0   0             0
# 3             5.886104         8.505323     1    1  0  0   0             1
# 4             5.886104         8.699515     1    0  0  0   0             0
#
#    Yes  Semiurban  Urban
# 0    0          0      1
# 1    0          0      0
# 2    1          0      1
# ...

# %%
#specify input and output attributes
x=df.drop(columns=['Loan_Status'],axis=1)
y=df['Loan_Status']

# %%
x
# Out:
#      Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_TermLog  \
# 0               1.0            8.674026       4.857444             5.886104
# 1               1.0            8.430109       4.852030             5.886104
# 2               1.0            8.006368       4.189655             5.886104
# 3               1.0            7.856707       4.787492             5.886104
# 4               1.0            8.699515       4.948760             5.886104
# ..              ...                 ...            ...                  ...
# 609             1.0            7.972466       4.262680             5.886104
# 610             1.0            8.320205       3.688879             5.192957
# 611             1.0            8.996157       5.533389             5.886104
# 612             1.0            8.933664       5.231109             5.886104
# 613             0.0            8.430109       4.890349             5.886104
#
# ...

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.head()
# Out:
#      Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_TermLog  \
# 92              1.0            8.093462       4.394449             5.886104
# 304             1.0            8.294050       4.941642             5.886104
# 68              1.0            8.867850       4.828314             4.094345
# 15              1.0            8.507143       4.828314             5.886104
# 211             0.0            8.140316       4.852030             5.886104
#
#      Total_incomeLog  Male  Yes  1  2  3+  Not Graduate  Yes  Semiurban  Urban
# 92          8.535622     1    1  0  1   0             1    0          0      1
# 304         8.779557     1    0  0  0   0             0    0          0      0
# 68          8.867850     1    1  0  0   1             1    1          0      1
# 15          8.507143     1    0  0  0   0             0    0          0      1
# 211         8.451053     1    1  0  0   1             0    0          1      0

# %%
y_train.head()
# Out:
# 92     Y
# 304    Y
# 68     Y
# 15     Y
# 211    N
# Name: Loan_Status, dtype: object

# %%
y_test.head()
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
# Name: Loan_Status, dtype: object

# %%
y_train.head()
# Out:
# 92     Y
# 304    Y
# 68     Y
# 15     Y
# 211    N
# Name: Loan_Status, dtype: object

# %%
x_test.head()
# Out:
#      Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_TermLog  \
# 350        1.000000            9.114160       5.429346             5.886104
# 377        0.842199            8.368693       4.867534             5.886104
# 163        1.000000            8.334952       5.062595             5.886104
# 609        1.000000            7.972466       4.262680             5.886104
# 132        1.000000            7.907652       4.248495             5.886104
#
#      Total_incomeLog  Male  Yes  1  2  3+  Not Graduate  Yes  Semiurban  Urban
# 350         9.114160     1    1  0  0   0             0    0          1      0
# 377         8.368693     1    1  0  0   0             0    0          1      0
# 163         8.633019     1    1  0  1   0             0    0          0      0
# 609         7.972466     0    0  0  0   0             0    0          0      0
# 132         7.907652     1    0  0  0   0             0    0          1      0

# %%
#model trainning
# randomforest classifier
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print("accuracy is ",model.score(x_test,y_test)*100)
# Out:
# accuracy is  77.92207792207793

# %%
 #decision tree classifier
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("accuracy is:-",model2.score(x_test,y_test)*100)
# Out:
# accuracy is:- 64.28571428571429

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
model3=LogisticRegression()
model3.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("accuracy is:-",model3.score(x_test,y_test)*100)
# Out:
# accuracy is:- 77.27272727272727

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
y_pred=model.predict(x_test)
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[27, 27],
#        [25, 75]], dtype=int64)

# %%
import pickle
file=open("model.pkl", 'wb')
pickle.dump(model, file)
